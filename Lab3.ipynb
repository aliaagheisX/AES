# %% [markdown]
# <a href="https://colab.research.google.com/github/aliaagheisX/AES/blob/master/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Students Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: Aliaa Abdelazize Ali Gheis
#    **ID**: `9210694`
#
# 2. **Name**: Ahmed Osama Helmy
#    **ID**: `9XXXXXX`

# %% [markdown]
# ## Students Instructions
#
# This is your 3rd graded lab assignment, as you put the work you have studied in the lectures in action, please take this opportunity to enhance your understanding of the concepts and hone your skills.
#
#
# Feel free to [reach out](mailto:noran.mostafa00@eng-st.cu.edu.eg) if you have any questions.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, send an email with your notebook and any additional files. Email's subject should be "ST-Lab3-ID1-ID2"
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
#
# We look forward to seeing your completed projects and wish you the best of luck!

# %% [markdown]
# ## Installation Instructions
#
# In this lab assignment, we require additional Python libraries for machine learning (ML) and deep learning (DL) algorithms and frameworks. To fulfill these requirements, we need to install Pytorch.
# 1. Install Pytorch \
# PyTorch is a versatile and powerful machine learning library for Python, known for its flexibility and ease of use in research and production. It supports various deep learning operations and models, including convolutional and recurrent neural networks. For Windows users, the installation also requires ensuring that CUDA, provided by NVIDIA, is compatible to enable GPU acceleration. This enhances performance significantly, particularly in training large neural networks.\
# For windows installation with GPU support you can [check out this link](https://pytorch.org/get-started/locally/) which is the source for the command below and please know that support for GPU is done for windows so you can also check out [previous versions](https://pytorch.org/get-started/previous-versions/), you could use CPU on windows smoothly, use linux or resort to [WSL](https://www.youtube.com/watch?v=R4m8YEixidI).
#
# ```bash
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# ```
# ```bash
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# ```

# %% [markdown]
# > **Note:** You are allowed to install any other necessary libraries you deem useful for solving the lab. Please ensure that any additional libraries are compatible with the project requirements and are properly documented in your submission.

# %%
# !gdown 1SeliSqjYUmxBfXkNfXLdfvGHBW-39Gyk
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1SeliSqjYUmxBfXkNfXLdfvGHBW-39Gyk
# From (redirected): https://drive.google.com/uc?id=1SeliSqjYUmxBfXkNfXLdfvGHBW-39Gyk&confirm=t&uuid=c40c2545-7e04-45e4-b77d-b5ef5761f8e2
# To: /content/EuroSATallBands.zip
# 100% 2.07G/2.07G [00:27<00:00, 76.2MB/s]

# %%
# !unzip EuroSATallBands.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_145.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1450.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1451.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1452.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1453.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1454.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1455.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1456.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1457.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1458.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1459.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_146.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1460.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1461.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1462.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1463.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1464.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1465.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1466.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1467.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1468.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1469.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_147.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1470.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1471.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1472.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1473.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1474.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1475.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1476.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1477.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1478.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1479.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_148.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1480.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1481.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1482.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1483.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1484.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1485.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1486.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1487.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1488.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1489.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_149.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1490.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1491.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1492.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1493.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1494.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1495.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1496.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1497.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1498.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1499.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_15.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_150.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1500.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1501.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1502.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1503.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1504.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1505.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1506.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1507.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1508.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1509.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_151.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1510.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1511.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1512.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1513.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1514.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1515.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1516.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1517.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1518.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1519.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_152.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1520.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1521.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1522.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1523.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1524.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1525.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1526.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1527.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1528.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1529.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_153.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1530.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1531.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1532.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1533.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1534.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1535.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1536.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1537.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1538.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1539.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_154.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1540.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1541.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1542.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1543.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1544.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1545.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1546.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1547.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1548.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1549.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_155.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1550.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1551.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1552.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1553.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1554.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1555.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1556.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1557.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1558.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1559.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_156.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1560.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1561.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1562.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1563.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1564.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1565.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1566.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1567.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1568.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1569.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_157.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1570.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1571.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1572.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1573.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1574.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1575.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1576.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1577.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1578.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1579.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_158.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1580.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1581.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1582.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1583.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1584.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1585.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1586.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1587.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1588.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1589.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_159.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1590.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1591.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1592.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1593.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1594.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1595.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1596.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1597.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1598.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1599.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_16.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_160.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1600.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1601.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1602.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1603.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1604.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1605.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1606.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1607.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1608.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1609.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_161.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1610.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1611.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1612.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1613.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1614.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1615.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1616.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1617.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1618.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1619.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_162.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1620.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1621.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1622.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1623.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1624.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1625.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1626.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1627.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1628.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1629.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_163.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1630.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1631.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1632.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1633.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1634.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1635.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1636.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1637.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1638.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1639.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_164.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1640.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1641.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1642.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1643.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1644.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1645.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1646.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1647.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1648.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1649.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_165.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1650.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1651.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1652.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1653.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1654.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1655.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1656.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1657.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1658.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1659.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_166.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1660.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1661.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1662.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1663.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1664.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1665.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1666.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1667.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1668.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1669.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_167.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1670.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1671.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1672.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1673.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1674.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1675.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1676.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1677.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1678.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1679.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_168.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1680.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1681.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1682.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1683.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1684.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1685.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1686.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1687.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1688.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1689.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_169.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1690.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1691.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1692.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1693.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1694.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1695.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1696.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1697.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1698.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1699.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_17.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_170.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1700.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1701.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1702.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1703.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1704.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1705.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1706.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1707.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1708.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1709.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_171.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1710.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1711.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1712.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1713.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1714.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1715.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1716.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1717.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1718.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1719.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_172.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1720.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1721.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1722.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1723.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1724.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1725.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1726.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1727.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1728.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1729.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_173.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1730.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1731.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1732.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1733.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1734.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1735.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1736.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1737.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1738.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1739.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_174.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1740.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1741.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1742.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1743.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1744.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1745.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1746.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1747.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1748.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1749.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_175.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1750.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1751.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1752.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1753.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1754.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1755.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1756.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1757.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1758.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1759.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_176.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1760.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1761.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1762.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1763.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1764.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1765.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1766.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1767.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1768.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1769.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_177.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1770.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1771.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1772.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1773.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1774.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1775.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1776.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1777.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1778.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1779.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_178.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1780.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1781.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1782.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1783.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1784.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1785.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1786.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1787.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1788.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1789.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_179.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1790.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1791.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1792.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1793.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1794.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1795.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1796.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1797.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1798.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1799.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_18.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_180.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1800.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1801.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1802.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1803.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1804.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1805.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1806.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1807.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1808.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1809.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_181.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1810.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1811.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1812.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1813.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1814.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1815.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1816.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1817.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1818.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1819.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_182.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1820.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1821.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1822.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1823.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1824.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1825.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1826.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1827.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1828.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1829.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_183.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1830.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1831.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1832.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1833.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1834.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1835.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1836.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1837.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1838.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1839.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_184.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1840.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1841.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1842.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1843.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1844.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1845.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1846.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1847.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1848.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1849.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_185.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1850.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1851.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1852.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1853.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1854.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1855.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/River/River_1856.tif
# ...
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_868.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_869.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_87.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_870.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_871.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_872.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_873.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_874.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_875.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_876.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_877.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_878.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_879.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_88.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_880.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_881.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_882.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_883.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_884.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_885.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_886.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_887.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_888.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_889.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_89.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_890.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_891.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_892.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_893.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_894.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_895.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_896.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_897.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_898.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_899.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_9.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_90.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_900.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_901.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_902.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_903.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_904.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_905.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_906.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_907.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_908.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_909.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_91.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_910.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_911.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_912.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_913.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_914.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_915.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_916.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_917.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_918.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_919.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_92.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_920.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_921.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_922.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_923.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_924.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_925.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_926.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_927.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_928.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_929.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_93.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_930.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_931.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_932.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_933.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_934.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_935.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_936.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_937.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_938.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_939.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_94.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_940.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_941.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_942.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_943.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_944.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_945.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_946.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_947.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_948.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_949.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_95.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_950.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_951.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_952.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_953.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_954.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_955.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_956.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_957.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_958.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_959.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_96.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_960.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_961.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_962.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_963.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_964.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_965.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_966.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_967.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_968.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_969.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_97.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_970.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_971.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_972.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_973.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_974.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_975.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_976.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_977.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_978.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_979.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_98.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_980.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_981.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_982.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_983.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_984.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_985.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_986.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_987.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_988.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_989.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_99.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_990.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_991.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_992.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_993.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_994.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_995.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_996.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_997.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_998.tif
#   inflating: EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/SeaLake/SeaLake_999.tif

# %%
# !ls EuroSATallBands
# Out:
# ds

# %% [markdown]
# ## Convolutional Neural Networks (CNN)
#
# Machine learning is a field of artificial intelligence that enables systems to learn from data and make decisions without being explicitly programmed. It involves algorithms that iteratively learn from data and improve their accuracy over time by optimizing an error metric, typically through the use of loss functions. These functions quantify the difference between the predicted outputs and the actual outputs, guiding the algorithm to minimize this error during training. By continually adjusting and improving, machine learning models can achieve remarkable accuracy in tasks ranging from simple classification to complex decision-making scenarios.
#
# Convolutional Neural Networks (CNNs) are a specialized kind of neural networks particularly effective for analyzing visual imagery. They employ a mathematical operation known as convolution, which uses sliding window techniques to process data. This method is highly efficient in recognizing patterns and features in images due to the sparse interactions and parameter sharing of convolutional layers. These characteristics allow CNNs to capture local patterns like edges and textures with a significantly reduced amount of parameters compared to fully connected networks, making them highly efficient for tasks involving high-dimensional data like images.
#
# ### Key Components of CNN Architecture
#
# The architecture of a Convolutional Neural Network (CNN) typically includes several key components, each playing a crucial role in the network's ability to process and interpret visual information:
#
# - **Convolutional Layers**:
#   - Apply a number of filters to the input.
#   - Create feature maps that capture essential details within the data.
#
# - **Pooling Layers**:
#   - Often follow convolutional layers.
#   - Reduce the spatial size of the feature maps, decreasing the computational load.
#   - Extract dominant features that are invariant to small changes in the input.
#
# - **Fully Connected Layers**:
#   - Interpret the features extracted by convolutional and pooling layers.
#   - Perform classification or regression tasks based on the interpreted features.
#
# - **Softmax Layer**:
#   - Typically used in the final layer if the task is classification.
#   - Outputs the probabilities of the instance belonging to each class.
#
# - **Dropout Layers**:
#   - Included to prevent overfitting.
#   - Randomly drop units from the neural network during the training process to improve generalization.

# %% [markdown]
# ### Example of CNN Architecture: LeNet-5
#
# ![Example: LeNet-5 Architecture](lenet5.png)

# %% [markdown]
# ### Overview of Neural Network Hyperparameters
#
# In training neural networks, various hyperparameters must be predefined to guide the training process. These include:
#
# - **Batch Size**
#   - **Definition**: Number of training examples used per iteration.
#   - **Common Values**: 32, 64, 128, 256.
#
# - **Learning Rate**
#   - **Definition**: Step size at each iteration to minimize the loss function.
#   - **Common Values**: Often starts small, e.g., 0.01, 0.001, and can be dynamically adjusted (lowered as we get nearer to minima, check scheduers).
#
# - **Optimizer Type**
#   - **Examples**: SGD (Stochastic Gradient Descent), Adam, RMSprop, Adagrad.
#   - **Role**: Different optimizers affect training dynamics and model performance differently.
#
# - **Beta Parameters for Adam Optimizer**
#   - **Beta1 and Beta2**: Control the decay rates of moving averages of past gradients and squared gradients.
#   - **Common Values**: Beta1 = 0.9, Beta2 = 0.999.
#
# - **Epochs**
#   - **Definition**: One full pass of the training dataset through the learning algorithm.
#   - **Usage**: More epochs can lead to better learning but risk overfitting.
#
# - **Momentum**
#   - **Definition**: Helps accelerate SGD and dampens oscillations.
#   - **Common Values**: 0.9, 0.99.
#
# - **Regularization Parameters (L1 & L2)**
#   - **Purpose**: Prevent overfitting by adding a penalty on the size of the coefficients.
#   - **Parameters**: Lambda or alpha values for L1 (Lasso) and L2 (Ridge) regularization.
#
# - **Dropout Rate**
#   - **Definition**: Fraction of neurons to randomly drop during training.
#   - **Common Values**: 0.2, 0.3, 0.5.
#
# - **Number of Layers and Number of Neurons in Each Layer**
#   - **Role**: Determines the architecture's depth and width, affecting its ability to capture complex patterns.
#
# - **Error Function Type for Classification with Softmax**
#   - **Definition**: Cross-entropy loss, also known as log loss.
#   - **Purpose**: Measures the performance of a classification model whose output is a probability value between 0 and 1. Cross-entropy loss increases as the predicted probability diverges from the actual label (an alternative can be Categorical Hinge Loss).
#
# - **Early Stopping**
#   - **Purpose**: Halt training when performance on a validation set starts to worsen to prevent overfitting.
#
# Each of these hyperparameters can significantly impact the effectiveness and efficiency of the neural network training process, and tuning them appropriately is crucial for achieving optimal performance.

# %% [markdown]
# ## Req- Image Classification for EuroSATallBands
# This is the same problem of the previous lab but we will explore the power of machine learning. Image classification in remote sensing is not as popular as pixel classification but we will get to that later.
#
# - **Load the Images**: Load the images of the EuroSAT dataset that belong to the **residential**, **river**, and **forest** classes.
#
# - **Split the Dataset**: Split the dataset such that 10% of each class is used as validation data and other 10% is used as testing data, and the remainder is used for training your classifier. Use the indices provided by `np.random.choice` with seed set to `27`. **Code is provided do not change it**.
#
# - **CNN Architecture**: Use or implement one of the popular suitable CNN architectures, even with pretrained weights if you like.
#
# - **Hyperparameters Tuning**: According to your validation accuaracy, you should make altercations to your architectures and hyperparameters, you can even change the architecture altogether, the loss function, optimizer or others.
#
# - **Report Accuracy and Average F1 Score**: After testing your classifier on the test set, report the **Accuracy** and **Average F1 Score** of your model.

# %%
# Add your libraries here
import numpy as np

# %%
# DO NOT CHANGE THIS CELL
## Training set indices.
np.random.seed(27)  # Set random seed for reproducibility

# Randomly select indices for the test sets for each class
residential_indices = np.random.choice(np.arange(3000), size=600, replace=False)
forest_indices = np.random.choice(np.arange(3000), size=600, replace=False)
river_indices = np.random.choice(np.arange(2500), size=500, replace=False)

residential_val_indices = residential_indices[:300]
forest_val_indices = forest_indices[:300]
river_val_indices = river_indices[:250]

residential_test_indices = residential_indices[300:]
forest_test_indices = forest_indices[300:]
river_test_indices = river_indices[250:]

# %%
all_residential = np.arange(3000)
all_forest = np.arange(3000)
all_river = np.arange(2500)

residential_train_indices = np.setdiff1d(all_residential, residential_indices)
forest_train_indices = np.setdiff1d(all_forest, forest_indices)
river_train_indices = np.setdiff1d(all_river, river_indices)

# %% [markdown]
# ### Grading Criteria (Total: 10 Marks)
#
# The lab is graded based on the following criteria:
#
# 1. **Data Loading and Preparation (2 Marks)**
#    - Correctly loads images for the residential, river, and forest classes. (1 Mark)
#    - Accurately splits the dataset into training, validation testing subsets and clearly shows this split. (1 Mark)
#
# 2. **CNN Architecture (3 Marks)**
#    - Uses appropriate CNN Architecture to the problem with a full pipeline. (2 Marks)
#    - Justifies the selection of CNN architecture. (1 Mark)
#
# 3. **Hyperparameters Tuning (2 Marks)**
#    - Report evaluation metrics on validation set. (1 Mark)
#    - Analyzes results and tunes hyperparameters. (1 Mark)
#
# 4. **Model Evaluation and Understanding (3 Marks)**
#    - Shows **confusion matrix** and correctly calculates and clearly shows the calculations for Accuracy and Average F1 Score. (1 Mark)
#    - consider visualizing and analyzing samples of the misclassified samples to understand patterns in the model’s errors.
#
# Each section of the lab will be evaluated on completeness, and correctness in approach and analysis. Part of the grade also includes the student's ability to explain and justify their choices and results.

# %%
# !pip install earthpy gdal
# Out:
# Collecting earthpy
#   Downloading earthpy-0.9.4-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: gdal in /usr/local/lib/python3.11/dist-packages (3.6.4)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from earthpy) (1.0.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from earthpy) (3.10.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from earthpy) (2.0.2)
# Collecting rasterio (from earthpy)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from earthpy) (0.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from earthpy) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->earthpy) (2.8.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (0.10.0)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->earthpy) (2.0.7)
# Collecting affine (from rasterio->earthpy)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio->earthpy) (8.1.8)
# Collecting cligj>=0.5 (from rasterio->earthpy)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->earthpy)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->earthpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->earthpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->earthpy) (2.3.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->earthpy) (0.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas->earthpy) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas->earthpy) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->earthpy) (1.17.0)
# Downloading earthpy-0.9.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.5 MB/s eta 0:00:00
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 78.9 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio, earthpy
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 earthpy-0.9.4 rasterio-1.4.3

# %%
import copy

from PIL import Image
from tqdm.auto import tqdm

import torch
import torch.nn as nn
from torch.functional import F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from osgeo import gdal, gdal_array
import earthpy.plot as ep
import earthpy.spatial as es
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt

import albumentations as A

# torch.set_manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generator = torch.Generator(device="cpu").manual_seed(42)
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Data Loading & Perperation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

# DATA_PATH =  Path("drive/MyDrive/Satellite Labs/EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif")
DATA_PATH =  Path("EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif")

RIVER_PATH =  DATA_PATH / "River"
FOREST_PATH =  DATA_PATH / "Forest"
RESD_PATH =  DATA_PATH / "Residential"

# %%
print("Length of Images in River ", len(list(RIVER_PATH.rglob("*.tif"))))
print("Length of Images in Forest ", len(list(FOREST_PATH.rglob("*.tif"))))
print("Length of Images in Residential ", len(list(RESD_PATH.rglob("*.tif"))))
# Out:
# Length of Images in River  2500
# Length of Images in Forest  3000
# Length of Images in Residential  3000

# %%
classes = ["river", "forest", "residential"]

classes_data = {
    "train": {
        "river": river_train_indices,
        "forest": forest_train_indices,
        "residential": residential_train_indices
    },
    "val": {
        "river": river_val_indices,
        "forest": forest_val_indices,
        "residential": residential_val_indices
    },
    "test": {
        "river": river_test_indices,
        "forest": forest_test_indices,
        "residential": residential_test_indices
    }
}

classes_path = {
    "river": RIVER_PATH,
    "forest": FOREST_PATH,
    "residential": RESD_PATH
}

classes_encoded = {
    "river": 0,
    "forest": 1,
    "residential": 2
}

# %%
def get_image_name(target, idx):
  return f"{target.title()}_{idx}.tif"

def get_image(target: str, idx):
  """ given target class and image idx
      return array of size: (C, H, W)(13, 64, 64)
  """
  img_name = get_image_name(target, idx)
  img_path = classes_path[target] / img_name
  # print(img_path)
  assert(img_path.exists())

  img_ds = gdal.Open(str(img_path), gdal.GA_ReadOnly)

  return img_ds.ReadAsArray()

def standardize_bands(image):
    """
        Standardized image (mean=0, std=1 per band)
    """
    mean = np.mean(image, axis=(1, 2), keepdims=True)
    std = np.std(image, axis=(1, 2), keepdims=True)
    return (image - mean) / (std + 1e-6)

# %%
class EuroSatDataset(Dataset):
    def __init__(self, split="train", transform=None):
        self.all_indices = [(target, int(img_idx) + 1) for target, indices in classes_data[split].items() for img_idx in indices ]
        #TODO: add augmentations
        self.transform = transform
    def __len__(self):
        return len(self.all_indices)

    def __getitem__(self, idx):
        target, img_idx = self.all_indices[idx]
        # read and standarize image
        image_np = standardize_bands(get_image(target, img_idx))

        if self.transform:
            image_np = self.transform(image=image_np)

        return torch.tensor(image_np, dtype=torch.float32), classes_encoded[target]

# %%
train_dataset = EuroSatDataset()
val_dataset = EuroSatDataset(split="val")
test_dataset = EuroSatDataset(split="test")

# %%
sample, sample_target = train_dataset[0]

# %%
batch_size = 128 #@param

train_loader = DataLoader(train_dataset, batch_size, shuffle=True, generator=generator)
val_loader = DataLoader(val_dataset, batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False)

# %%
# next(iter(train_loader))

# %% [markdown]
# # CNN

# %% [markdown]
# ## LeNet-5 Variant

# %%
def get_conv_wout(win, kernal = 3, padd = 0, stride = 1):
  return (win - kernal + 2*padd)//stride + 1

def get_pool_wout(win, kernal = 2, stride = 2):
  return (win - kernal)//stride + 1
# get_conv_wout(64, 5, 0)

# %%
class LeNetEuroSAT(nn.Module):
  """ this kinda variant of LeNet5

      - using MaxPool instead of AvgPool (more popular choice)
      - using Relu instead of Tanh (more popular choice)
      - normal 2nd Convolution layer :xd
  """
  def __init__(self, in_channels = 13, num_classes = 3):
    super().__init__()
    self.conv1 = nn.Conv2d(in_channels, 6, 5, padding=2) # 6x64x64
    self.pool1 = nn.MaxPool2d(2) # 6x32x32
    self.conv2 = nn.Conv2d(6, 16, 5) # 16x28x28
    self.pool2 = nn.MaxPool2d(2) # 16x14x14
    self.fc1 = nn.Linear(16*14*14, 120)  # 14x14
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, num_classes)

  def forward(self, x):

    x = self.pool1( F.relu(self.conv1(x)) )
    x = self.pool2( F.relu(self.conv2(x)) )

    x = torch.flatten(x, 1)

    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))

    return self.fc3(x)

# %%
def get_inference_metrics(model, loader, criterion):
  model.eval()
  total_loss = 0.0
  all_preds = []
  all_labels = []

  for step, (inputs, labels) in tqdm(enumerate(loader), total = len(loader)):
    inputs = inputs.to(device)
    labels = labels.long().to(device)

    with torch.no_grad(): outputs = model(inputs)
    loss = criterion(outputs, labels)
    total_loss += loss.item()

    _, preds = torch.max(outputs, 1)
    all_preds.extend(preds.cpu().numpy())
    all_labels.extend(labels.cpu().numpy())

  metrics = {
    'loss': total_loss / len(loader),
    'accuracy': accuracy_score(all_labels, all_preds),
    'f1_score': f1_score(all_labels, all_preds, average='weighted'),
    'precision': precision_score(all_labels, all_preds, average='weighted'),
    'recall': recall_score(all_labels, all_preds, average='weighted'),
    'confusion_matrix': confusion_matrix(all_labels, all_preds, )
  }

  return metrics


def get_inference_loss(model, loader, criterion):
  model.eval()
  total_loss = 0.0
  for step, (inputs, labels) in tqdm(enumerate(loader), total = len(loader)):
    inputs = inputs.to(device)
    labels = labels.long().to(device)

    with torch.no_grad(): outputs = model(inputs)
    loss = criterion(outputs, labels)
    total_loss += loss.item()

  return total_loss / len(loader)

def train_one_epoch(model, loader, optimizer, criterion):
  model.train()
  train_loss = 0.0
  for step, (inputs, labels) in tqdm(enumerate(loader), total = len(loader)):
    optimizer.zero_grad()
    inputs = inputs.to(device)
    labels = labels.long().to(device)
    # forward loop
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    # backward loop
    loss.backward()
    optimizer.step()

    train_loss += loss.item()

  return (train_loss / len(loader))

# %%
num_epochs = 20 #@param
lr = 1e-3 # @param
weight_decay = 1e-4 # @param # to not overfit on this small dataset
betas = (0.9, 0.999) #@title # default momentum
patience = 4 #@param # for early stopping

# %%
model = LeNetEuroSAT().to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr = lr, weight_decay=weight_decay, betas=betas)

# Learning Rate Scheduler
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',        # Monitor validation loss
    factor=0.5,        # Reduce LR by 50% on plateau
    patience=5,        # Wait 5 epochs before reducing
)

criterion = torch.nn.CrossEntropyLoss()

# %%
train_losses = []
val_losses = []
best_val_loss = float('inf')
epochs_no_improve = 0
best_model_lenet = None

for epoch in range(num_epochs):
  train_loss = train_one_epoch(model, train_loader, optimizer, criterion)
  val_loss = get_inference_loss(model, val_loader, criterion)

  lr_scheduler.step(val_loss)

  train_losses.append(train_loss)
  val_losses.append(val_loss)

  print(f"Epoch {epoch+1}: LR={lr_scheduler.get_last_lr()[0]:.2e},  Train Loss={train_loss:.4f},  Val Loss={val_loss:.4f}")

  if val_loss < best_val_loss:
    best_val_loss = val_loss
    best_model_lenet = copy.deepcopy(model)
    epochs_no_improve = 0
  else:
    epochs_no_improve += 1
    if epochs_no_improve >= patience:
      print(f"🚨 Early stopping triggered!")
      break
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 1: LR=1.00e-03,  Train Loss=0.0104,  Val Loss=0.0527
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 2: LR=1.00e-03,  Train Loss=0.0212,  Val Loss=0.0164
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 3: LR=1.00e-03,  Train Loss=0.0074,  Val Loss=0.0317
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 4: LR=1.00e-03,  Train Loss=0.0097,  Val Loss=0.2609
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 5: LR=1.00e-03,  Train Loss=0.0192,  Val Loss=0.0144
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 6: LR=1.00e-03,  Train Loss=0.0060,  Val Loss=0.0061
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 7: LR=1.00e-03,  Train Loss=0.0041,  Val Loss=0.0104
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 8: LR=1.00e-03,  Train Loss=0.0156,  Val Loss=0.0155
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 9: LR=1.00e-03,  Train Loss=0.0248,  Val Loss=0.1757
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 10: LR=1.00e-03,  Train Loss=0.0557,  Val Loss=0.2284
# 🚨 Early stopping triggered!

# %%
val_metrics = get_inference_metrics(best_model_lenet, val_loader, criterion)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
val_metrics
# Out:
# {'loss': 0.020969676889113283,
#  'accuracy': 0.991764705882353,
#  'f1_score': 0.9917589884966862,
#  'precision': 0.9918017382957,
#  'recall': 0.991764705882353,
#  'confusion_matrix': array([[248,   1,   1],
#         [  4, 295,   1],
#         [  0,   0, 300]])}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(val_metrics['confusion_matrix'], display_labels=['river', 'forest', 'residential'])

disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Resnet18
# just for fun :xd

# %%
class ResidualBlock(nn.Module):
  def __init__(self, in_channels, out_channels, stride = 1, downsample = None):
    super(ResidualBlock, self).__init__()
    self.conv1 = nn.Sequential(
                    nn.Conv2d(in_channels, out_channels, kernel_size = 3, stride = stride, padding = 1),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU())
    self.conv2 = nn.Sequential(
                    nn.Conv2d(out_channels, out_channels, kernel_size = 3, stride = 1, padding = 1),
                    nn.BatchNorm2d(out_channels))

    # handle mismatch of residual
    self.shortcut = nn.Sequential()
    if stride != 1 or in_channels != out_channels:
      self.shortcut = nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
        nn.BatchNorm2d(out_channels)
      )


  def forward(self, x):
    out = self.conv1(x)
    out = self.conv2(out)
    out += self.shortcut(x)
    return F.relu(out)

# %%
class ResNet18(nn.Module):
  def __init__(self, in_channels = 13, num_classes=3):
    super().__init__()
    self.in_channels = 64 # to propgate in layers # later
    self.conv1 = nn.Sequential(
        nn.Conv2d(in_channels, 64, kernel_size=3, stride=1, padding=1, bias=False),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
    )
    self.layer1 = self._make_layer(ResidualBlock, 64, 2, stride=1)
    self.layer2 = self._make_layer(ResidualBlock, 128, 2, stride=2)
    self.layer3 = self._make_layer(ResidualBlock, 256, 2, stride=2)
    self.layer4 = self._make_layer(ResidualBlock, 512, 2, stride=2)

    self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
    self.fc = nn.Linear(512, num_classes)

  def _make_layer(self, block, out_channels, num_blocks, stride):
    strides = [stride] + [1] * (num_blocks - 1) # rest of block is 1 stride
    layers = []
    for stride in strides:
      layers.append(block(self.in_channels, out_channels, stride))
      self.in_channels = out_channels
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)

    out = self.avgpool(out)
    out = out.view(out.size(0), -1)
    out = self.fc(out)
    return out

# %%
num_epochs = 15 #@param
lr = 1e-3 # @param
weight_decay = 1e-4 # @param # to not overfit on this small dataset
betas = (0.9, 0.999) #@title # default momentum
patience = 4 #@param # for early stopping

# %%
model = ResNet18().to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr = lr, weight_decay=weight_decay, betas=betas)

# Learning Rate Scheduler
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',        # Monitor validation loss
    factor=0.5,        # Reduce LR by 50% on plateau
    patience=5,        # Wait 5 epochs before reducing
)

criterion = torch.nn.CrossEntropyLoss()

# %%
train_losses = []
val_losses = []
best_val_loss = float('inf')
epochs_no_improve = 0
best_model_resnet = None

for epoch in range(num_epochs):
  train_loss = train_one_epoch(model, train_loader, optimizer, criterion)
  val_loss = get_inference_loss(model, val_loader, criterion)

  lr_scheduler.step(val_loss)

  train_losses.append(train_loss)
  val_losses.append(val_loss)

  print(f"Epoch {epoch+1}: LR={lr_scheduler.get_last_lr()[0]:.2e},  Train Loss={train_loss:.4f},  Val Loss={val_loss:.4f}")

  if val_loss < best_val_loss:
    best_val_loss = val_loss
    best_model_resnet = copy.deepcopy(model)
    epochs_no_improve = 0
  else:
    epochs_no_improve += 1
    if epochs_no_improve >= patience:
      print(f"🚨 Early stopping triggered!")
      break
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 1: LR=1.00e-03,  Train Loss=0.3262,  Val Loss=1.4908
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 2: LR=1.00e-03,  Train Loss=0.0372,  Val Loss=0.0803
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 3: LR=1.00e-03,  Train Loss=0.0476,  Val Loss=0.1283
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 4: LR=1.00e-03,  Train Loss=0.0645,  Val Loss=0.0754
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 5: LR=1.00e-03,  Train Loss=0.0241,  Val Loss=0.1763
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 6: LR=1.00e-03,  Train Loss=0.0275,  Val Loss=0.0077
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 7: LR=1.00e-03,  Train Loss=0.0196,  Val Loss=0.0210
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 8: LR=1.00e-03,  Train Loss=0.0271,  Val Loss=0.3152
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 9: LR=1.00e-03,  Train Loss=0.0289,  Val Loss=0.0109
#   0%|          | 0/54 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 10: LR=1.00e-03,  Train Loss=0.0083,  Val Loss=0.0936
# 🚨 Early stopping triggered!

# %%
val_metrics = get_inference_metrics(best_model_resnet, val_loader, criterion)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
val_metrics
# Out:
# {'loss': 0.0077122088821072665,
#  'accuracy': 0.9976470588235294,
#  'f1_score': 0.9976472509170012,
#  'precision': 0.9976517459573472,
#  'recall': 0.9976470588235294,
#  'confusion_matrix': array([[250,   0,   0],
#         [  1, 299,   0],
#         [  0,   1, 299]])}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(val_metrics['confusion_matrix'], display_labels=['river', 'forest', 'residential'])

disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## Testing

# %%
test_metrics_lenet =  get_inference_metrics(best_model_lenet, test_loader, criterion)
test_metrics_resnet =  get_inference_metrics(best_model_resnet, test_loader, criterion)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
test_metrics_lenet
# Out:
# {'loss': 0.004977780527302197,
#  'accuracy': 0.9976470588235294,
#  'f1_score': 0.9976470555555464,
#  'precision': 0.9976509673636896,
#  'recall': 0.9976470588235294,
#  'confusion_matrix': array([[249,   0,   1],
#         [  1, 299,   0],
#         [  0,   0, 300]])}

# %%
test_metrics_lenet
# Out:
# {'loss': 0.004977780527302197,
#  'accuracy': 0.9976470588235294,
#  'f1_score': 0.9976470555555464,
#  'precision': 0.9976509673636896,
#  'recall': 0.9976470588235294,
#  'confusion_matrix': array([[249,   0,   1],
#         [  1, 299,   0],
#         [  0,   0, 300]])}
